# %% [markdown]
# GenePattern Notebook Setup

# %%
# imports python modules required to run GenePattern Notebook App

import os
import sys
sys.path.append('../Client')
import genepattern as gp
import broadprotocol as bp

# record genepattern server url and account information

GenePattern_Server_URL = "http://genepattern.broadinstitute.org/gp/" # @param
userID = "CBB.test" # @param
password = "password" # @param

serverData = gp.ServerData(GenePattern_Server_URL, userID, password)
gp.SetServerData(serverData)

# initialize python session state
session_file = "/Users/birger/RNA_Seq_Notebook_sessionfile.json" # @param
if os.path.isfile(session_file):
  session_state = bp.load_session_state(session_file)
else:
  session_state = {}

# %%
bp.print_dict(session_state)

# %%
from collections import namedtuple
Phenotypes = namedtuple('Phenotypes', 'untreated treated')

donor_dict = {}
phenotypes_dict = {'untreated': None, 'treated': None}

untreated_data_dict = {'accession': "SRR1039508"}
treated_data_dict = {'accession': "SRR1039509"}
donor_dict["N061311"] = {"untreated": untreated_data_dict, "treated": treated_data_dict}
#donor_dict["N061311"] = Phenotypes(untreated_data_dict, treated_data_dict)

untreated_data_dict = {'accession': "SRR1039512"}
treated_data_dict = {'accession': "SRR1039513"}
donor_dict["N052611"] = {"untreated": untreated_data_dict, "treated": treated_data_dict}
#donor_dict["N052611"] = Phenotypes(untreated_data_dict, treated_data_dict)

untreated_data_dict = {'accession': "SRR1039516"}
treated_data_dict = {'accession': "SRR1039517"}
donor_dict["N080611"] = {"untreated": untreated_data_dict, "treated": treated_data_dict}
#donor_dict["N080611"] = Phenotypes(untreated_data_dict, treated_data_dict)

untreated_data_dict = {'accession': "SRR1039520"}
treated_data_dict = {'accession': "SRR1039521"}
donor_dict["N061011"] = {"untreated": untreated_data_dict, "treated": treated_data_dict}
#donor_dict["N061011"] = Phenotypes(untreated_data_dict, treated_data_dict)

session_state["donor_dict"] = donor_dict
bp.save_session_state(session_state, session_file)

# %%
bp.print_dict(session_state)
# Out:
# donor_dict
# 	N052611
# 		treated
# 			accession
# 				SRR1039513
# 		untreated
# 			accession
# 				SRR1039512
# 	N061311
# 		treated
# 			accession
# 				SRR1039509
# 		untreated
# 			accession
# 				SRR1039508
# 	N061011
# 		treated
# 			accession
# 				SRR1039521
# 		untreated
# 			accession
# 				SRR1039520
# 	N080611
# 		treated
# 			accession
# 				SRR1039517
# 		untreated
# 			accession
# 				SRR1039516

# %% [markdown]
# #STEP 1: Retrieve the SRA files from NCBI and convert them to FASTQ files

# %% [markdown]
# ## Widget-based job launch for single sample

# %%
#TBD

# %% [markdown]
# ## Widget-based retrieval of job status

# %% [markdown]
# #TBD

# %% [markdown]
# ## Programmatic launching of jobs for multiple samples

# %%
donor_dict = session_state["donor_dict"]
LSID = "urn:lsid:broad.mit.edu:cancer.software.genepattern.module.analysis:00344:0.5"
paired_end = "yes"
output_compression = "gzip"

for donor_id in donor_dict.keys():
    
    #untreated
    untreated_sample_data = donor_dict[donor_id]["untreated"]
    accession = untreated_sample_data['accession']
    #print accession
    job_spec = gp.JobSpec()
    job_spec.setLSID(LSID)
    job_spec.setParameter("accession", accession)
    job_spec.setParameter("paired.end", paired_end)
    job_spec.setParameter("output.compression", output_compression)
    job = gp.runJob(job_spec, waitUntilDone = False)
    untreated_sample_data['sraToFastq_job'] = job
                          
    #treated
    treated_sample_data = donor_dict[donor_id]["treated"]
    accession = treated_sample_data['accession']
    #print accession
    job_spec = gp.JobSpec()
    job_spec.setLSID(LSID)
    job_spec.setParameter("accession", accession)
    job_spec.setParameter("paired.end", paired_end)
    job_spec.setParameter("output.compression", output_compression)
    job = gp.runJob(job_spec, waitUntilDone = False)
    treated_sample_data['sraToFastq_job'] = job                          

bp.save_session_state(session_state, session_file)

# %%
## TESTING

donor_dict = session_state["donor_dict"]

## override session state with hardcoded job uri's from earlier run 

base_uri = "http://genepattern.broadinstitute.org/gp/rest/v1/jobs/"

donor_dict["N061311"]["untreated"]['sraToFastq_job'] = gp.GPJob(base_uri + "971929")
donor_dict["N061311"]["treated"]['sraToFastq_job'] = gp.GPJob(base_uri + "971929")


donor_dict["N052611"]["untreated"]['sraToFastq_job'] = gp.GPJob(base_uri + "971931")
donor_dict["N052611"]["treated"]['sraToFastq_job'] = gp.GPJob(base_uri + "971932")

donor_dict["N080611"]["untreated"]['sraToFastq_job'] = gp.GPJob(base_uri + "971933")
donor_dict["N080611"]["treated"]['sraToFastq_job'] = gp.GPJob(base_uri + "971934")

donor_dict["N061011"]["untreated"]['sraToFastq_job'] = gp.GPJob(base_uri + "971936")
donor_dict["N061011"]["treated"]['sraToFastq_job'] = gp.GPJob(base_uri + "971937")

bp.save_session_state(session_state, session_file)

# %%
bp.print_dict(donor_dict)
# Out:
# N052611
# 	treated
# 		sraToFastq_job
# 			<genepattern.GPJob object at 0x112a18450>
# 		accession
# 			SRR1039513
# 	untreated
# 		sraToFastq_job
# 			<genepattern.GPJob object at 0x112a18410>
# 		accession
# 			SRR1039512
# N061311
# 	treated
# 		sraToFastq_job
# 			<genepattern.GPJob object at 0x112a18390>
# 		accession
# 			SRR1039509
# 	untreated
# 		sraToFastq_job
# 			<genepattern.GPJob object at 0x112a183d0>
# 		accession
# 			SRR1039508
# N061011
# 	treated
# 		sraToFastq_job
# 			<genepattern.GPJob object at 0x112a18550>
# 		accession
# 			SRR1039521
# 	untreated
# 		sraToFastq_job
# 			<genepattern.GPJob object at 0x112a18510>
# 		accession
# 			SRR1039520
# N080611
# 	treated
# 		sraToFastq_job
# 			<genepattern.GPJob object at 0x112a184d0>
# 		accession
# 			SRR1039517
# 	untreated
# 		sraToFastq_job
# 			<genepattern.GPJob object at 0x112a18490>
# 		accession
# 			SRR1039516

# %%
session_state = bp.load_session_state(session_file)

# %%
donor_dict = session_state['donor_dict']
sraToFastq_jobs = []
for donor_id in donor_dict.keys():
    
    #untreated
    untreated_sample_data = donor_dict[donor_id]["untreated"]
    sraToFastq_jobs.append(untreated_sample_data['sraToFastq_job'])
    
    #treated
    treated_sample_data = donor_dict[donor_id]["treated"]
    sraToFastq_jobs.append(treated_sample_data['sraToFastq_job'])

# Poll GenePattern until all jobs associated with above code cell are complete
gp.pollMultipleJobs(sraToFastq_jobs)

for donor_id in donor_dict.keys():
    
    #untreated
    untreated_sample_data = donor_dict[donor_id]["untreated"]
    job = untreated_sample_data['sraToFastq_job']
    untreated_sample_data['sraToFastq_fwd_reads'] = [gpfile.uri for gpfile in job.getOutputFiles() if "_1.fastq" in gpfile.uri][0]
    untreated_sample_data['sraToFastq_rvs_reads'] = [gpfile.uri for gpfile in job.getOutputFiles() if "_2.fastq" in gpfile.uri][0]
    
    #treated
    treated_sample_data = donor_dict[donor_id]["treated"]
    job = treated_sample_data['sraToFastq_job']
    treated_sample_data['sraToFastq_fwd_reads'] = [gpfile.uri for gpfile in job.getOutputFiles() if "_1.fastq" in gpfile.uri][0]
    treated_sample_data['sraToFastq_rvs_reads'] = [gpfile.uri for gpfile in job.getOutputFiles() if "_2.fastq" in gpfile.uri][0]    
    

#save session state
bp.save_session_state(session_state, session_file)

# %%
bp.print_dict(donor_dict)
# Out:
# N052611
# 	treated
# 		sraToFastq_job
# 			<genepattern.GPJob object at 0x112a18450>
# 		sraToFastq_rvs_reads
# 			http://genepattern.broadinstitute.org/gp/jobResults/971932/SRR1039513_2.fastq.gz
# 		accession
# 			SRR1039513
# 		sraToFastq_fwd_reads
# 			http://genepattern.broadinstitute.org/gp/jobResults/971932/SRR1039513_1.fastq.gz
# 	untreated
# 		sraToFastq_job
# 			<genepattern.GPJob object at 0x112a18410>
# 		sraToFastq_rvs_reads
# 			http://genepattern.broadinstitute.org/gp/jobResults/971931/SRR1039512_2.fastq.gz
# 		accession
# 			SRR1039512
# 		sraToFastq_fwd_reads
# 			http://genepattern.broadinstitute.org/gp/jobResults/971931/SRR1039512_1.fastq.gz
# N061311
# 	treated
# 		sraToFastq_job
# 			<genepattern.GPJob object at 0x112a18390>
# 		sraToFastq_rvs_reads
# 			http://genepattern.broadinstitute.org/gp/jobResults/971929/SRR1039508_2.fastq.gz
# 		accession
# 			SRR1039509
# 		sraToFastq_fwd_reads
# 			http://genepattern.broadinstitute.org/gp/jobResults/971929/SRR1039508_1.fastq.gz
# 	untreated
# 		sraToFastq_job
# 			<genepattern.GPJob object at 0x112a183d0>
# 		sraToFastq_rvs_reads
# 			http://genepattern.broadinstitute.org/gp/jobResults/971929/SRR1039508_2.fastq.gz
# 		accession
# 			SRR1039508
# 		sraToFastq_fwd_reads
# 			http://genepattern.broadinstitute.org/gp/jobResults/971929/SRR1039508_1.fastq.gz
# N061011
# 	treated
# 		sraToFastq_job
# 			<genepattern.GPJob object at 0x112a18550>
# 		sraToFastq_rvs_reads
# 			http://genepattern.broadinstitute.org/gp/jobResults/971937/SRR1039521_2.fastq.gz
# 		accession
# 			SRR1039521
# 		sraToFastq_fwd_reads
# 			http://genepattern.broadinstitute.org/gp/jobResults/971937/SRR1039521_1.fastq.gz
# 	untreated
# 		sraToFastq_job
# 			<genepattern.GPJob object at 0x112a18510>
# 		sraToFastq_rvs_reads
# 			http://genepattern.broadinstitute.org/gp/jobResults/971936/SRR1039520_2.fastq.gz
# 		accession
# 			SRR1039520
# 		sraToFastq_fwd_reads
# 			http://genepattern.broadinstitute.org/gp/jobResults/971936/SRR1039520_1.fastq.gz
# N080611
# 	treated
# 		sraToFastq_job
# 			<genepattern.GPJob object at 0x112a184d0>
# 		sraToFastq_rvs_reads
# 			http://genepattern.broadinstitute.org/gp/jobResults/971934/SRR1039517_2.fastq.gz
# 		accession
# 			SRR1039517
# 		sraToFastq_fwd_reads
# 			http://genepattern.broadinstitute.org/gp/jobResults/971934/SRR1039517_1.fastq.gz
# 	untreated
# 		sraToFastq_job
# 			<genepattern.GPJob object at 0x112a18490>
# 		sraToFastq_rvs_reads
# 			http://genepattern.broadinstitute.org/gp/jobResults/971933/SRR1039516_2.fastq.gz
# 		accession
# 			SRR1039516
# 		sraToFastq_fwd_reads
# 			http://genepattern.broadinstitute.org/gp/jobResults/971933/SRR1039516_1.fastq.gz

# %% [markdown]
# #STEP 2: Run FastQC on all fastq files retrieved from NCBI

# %% [markdown]
# ## Widget-based job launch for single sample

# %% [markdown]
# ## Widget-based retrieval of job status

# %% [markdown]
# ## Programmatic launching of jobs for multiple samples

# %%
session_state = bp.load_session_state(session_file)

# %%
donor_dict = session_state["donor_dict"]
LSID = "urn:lsid:broad.mit.edu:cancer.software.genepattern.module.analysis:00340:0.5"

paired_end = "yes"
output_compression = "gzip"

for donor_id in donor_dict.keys():
    
    #untreated
    
    untreated_sample_data = donor_dict[donor_id]["untreated"]

    job_spec = gp.JobSpec()
    job_spec.setLSID(LSID)
    job_spec.setParameter("input.file", untreated_sample_data['sraToFastq_fwd_reads'])
    job = gp.runJob(job_spec, waitUntilDone = False)
    untreated_sample_data['fastqc_fwd_job'] = job

    job_spec = gp.JobSpec()
    job_spec.setLSID(LSID)
    job_spec.setParameter("input.file", untreated_sample_data['sraToFastq_rvs_reads'])
    job = gp.runJob(job_spec, waitUntilDone = False)
    untreated_sample_data['fastqc_rvs_job'] = job
    
    #treated
    
    treated_sample_data = donor_dict[donor_id]["treated"]
    
    job_spec = gp.JobSpec()
    job_spec.setLSID(LSID)
    job_spec.setParameter("input.file", treated_sample_data['sraToFastq_fwd_reads'])
    job = gp.runJob(job_spec, waitUntilDone = False)
    treated_sample_data['fastqc_fwd_job'] = job

    job_spec = gp.JobSpec()
    job_spec.setLSID(LSID)
    job_spec.setParameter("input.file", untreated_sample_data['sraToFastq_rvs_reads'])
    job = gp.runJob(job_spec, waitUntilDone = False)
    untreated_sample_data['fastqc_rvs_job'] = job                         

bp.save_session_state(session_state, session_file)

# %%
## TESTING

donor_dict = session_state["donor_dict"]

## override session state with hardcoded job uri's from earlier run 

base_uri = "http://genepattern.broadinstitute.org/gp/rest/v1/jobs/"

donor_dict["N061311"]["untreated"]['fastqc_fwd_job'] = gp.GPJob(base_uri + "974693")
donor_dict["N061311"]["untreated"]['fastqc_rvs_job'] = gp.GPJob(base_uri + "974694")
donor_dict["N061311"]["treated"]['fastqc_fwd_job'] = gp.GPJob(base_uri + "974697")
donor_dict["N061311"]["treated"]['fastqc_rvs_job'] = gp.GPJob(base_uri + "974698")

donor_dict["N052611"]["untreated"]['fastqc_fwd_job'] = gp.GPJob(base_uri + "974730")
donor_dict["N052611"]["untreated"]['fastqc_rvs_job'] = gp.GPJob(base_uri + "974731")
donor_dict["N052611"]["treated"]['fastqc_fwd_job'] = gp.GPJob(base_uri + "974734")
donor_dict["N052611"]["treated"]['fastqc_rvs_job'] = gp.GPJob(base_uri + "974735")

donor_dict["N080611"]["untreated"]['fastqc_fwd_job'] = gp.GPJob(base_uri + "974736")
donor_dict["N080611"]["untreated"]['fastqc_rvs_job'] = gp.GPJob(base_uri + "974737")
donor_dict["N080611"]["treated"]['fastqc_fwd_job'] = gp.GPJob(base_uri + "974741")
donor_dict["N080611"]["treated"]['fastqc_rvs_job'] = gp.GPJob(base_uri + "974742")

donor_dict["N061011"]["untreated"]['fastqc_fwd_job'] = gp.GPJob(base_uri + "974746")
donor_dict["N061011"]["untreated"]['fastqc_rvs_job'] = gp.GPJob(base_uri + "974747")
donor_dict["N061011"]["treated"]['fastqc_fwd_job'] = gp.GPJob(base_uri + "974751")
donor_dict["N061011"]["treated"]['fastqc_rvs_job'] = gp.GPJob(base_uri + "974751")

bp.save_session_state(session_state, session_file)

# %%
session_state = bp.load_session_state(session_file)
bp.print_dict(session_state)
# Out:
# donor_dict
# 	N052611
# 		treated
# 			fastqc_fwd_job
# 				<genepattern.GPJob object at 0x1128f64d0>
# 			accession
# 				SRR1039513
# 			sraToFastq_fwd_reads
# 				http://genepattern.broadinstitute.org/gp/jobResults/971932/SRR1039513_1.fastq.gz
# 			fastqc_fwd_report
# 				http://genepattern.broadinstitute.org/gp/jobResults/974734/SRR1039513_1_fastqc/fastqc_report.html
# 			fastqc_rvs_job
# 				<genepattern.GPJob object at 0x1128f6610>
# 			sraToFastq_job
# 				<genepattern.GPJob object at 0x1128f63d0>
# 			sraToFastq_rvs_reads
# 				http://genepattern.broadinstitute.org/gp/jobResults/971932/SRR1039513_2.fastq.gz
# 		untreated
# 			fastqc_rvs_report
# 				http://genepattern.broadinstitute.org/gp/jobResults/974731/SRR1039512_2_fastqc/fastqc_report.html
# 			fastqc_fwd_job
# 				<genepattern.GPJob object at 0x1128f6590>
# 			accession
# 				SRR1039512
# 			sraToFastq_fwd_reads
# 				http://genepattern.broadinstitute.org/gp/jobResults/971931/SRR1039512_1.fastq.gz
# 			fastqc_fwd_report
# 				http://genepattern.broadinstitute.org/gp/jobResults/974730/SRR1039512_1_fastqc/fastqc_report.html
# 			fastqc_rvs_job
# 				<genepattern.GPJob object at 0x1128f6410>
# 			sraToFastq_job
# 				<genepattern.GPJob object at 0x1128f6190>
# 			sraToFastq_rvs_reads
# 				http://genepattern.broadinstitute.org/gp/jobResults/971931/SRR1039512_2.fastq.gz
# 	N061311
# 		treated
# 			fastqc_fwd_job
# 				<genepattern.GPJob object at 0x112a8b250>
# 			accession
# 				SRR1039509
# 			sraToFastq_fwd_reads
# 				http://genepattern.broadinstitute.org/gp/jobResults/971929/SRR1039508_1.fastq.gz
# 			fastqc_fwd_report
# 				http://genepattern.broadinstitute.org/gp/jobResults/974697/SRR1039509_1_fastqc/fastqc_report.html
# 			fastqc_rvs_job
# 				<genepattern.GPJob object at 0x112a8bed0>
# 			sraToFastq_job
# 				<genepattern.GPJob object at 0x112a8b410>
# 			sraToFastq_rvs_reads
# 				http://genepattern.broadinstitute.org/gp/jobResults/971929/SRR1039508_2.fastq.gz
# 		untreated
# 			fastqc_rvs_report
# 				http://genepattern.broadinstitute.org/gp/jobResults/974694/SRR1039508_2_fastqc/fastqc_report.html
# 			fastqc_fwd_job
# 				<genepattern.GPJob object at 0x112a8b590>
# 			accession
# 				SRR1039508
# 			sraToFastq_fwd_reads
# 				http://genepattern.broadinstitute.org/gp/jobResults/971929/SRR1039508_1.fastq.gz
# 			fastqc_fwd_report
# 				http://genepattern.broadinstitute.org/gp/jobResults/974693/SRR1039508_1_fastqc/fastqc_report.html
# 			fastqc_rvs_job
# 				<genepattern.GPJob object at 0x112a8bd10>
# 			sraToFastq_job
# 				<genepattern.GPJob object at 0x112a8b090>
# 			sraToFastq_rvs_reads
# 				http://genepattern.broadinstitute.org/gp/jobResults/971929/SRR1039508_2.fastq.gz
# 	N061011
# 		treated
# 			fastqc_fwd_job
# 				<genepattern.GPJob object at 0x1128f6110>
# 			accession
# 				SRR1039521
# 			sraToFastq_fwd_reads
# 				http://genepattern.broadinstitute.org/gp/jobResults/971937/SRR1039521_1.fastq.gz
# 			fastqc_fwd_report
# 				http://genepattern.broadinstitute.org/gp/jobResults/974751/SRR1039521_1_fastqc/fastqc_report.html
# 			fastqc_rvs_job
# 				<genepattern.GPJob object at 0x1128f62d0>
# 			sraToFastq_job
# 				<genepattern.GPJob object at 0x1128f6390>
# 			sraToFastq_rvs_reads
# 				http://genepattern.broadinstitute.org/gp/jobResults/971937/SRR1039521_2.fastq.gz
# 		untreated
# 			fastqc_rvs_report
# 				http://genepattern.broadinstitute.org/gp/jobResults/974747/SRR1039520_2_fastqc/fastqc_report.html
# 			fastqc_fwd_job
# 				<genepattern.GPJob object at 0x112a8bf10>
# 			accession
# 				SRR1039520
# 			sraToFastq_fwd_reads
# 				http://genepattern.broadinstitute.org/gp/jobResults/971936/SRR1039520_1.fastq.gz
# 			fastqc_fwd_report
# 				http://genepattern.broadinstitute.org/gp/jobResults/974746/SRR1039520_1_fastqc/fastqc_report.html
# 			fastqc_rvs_job
# 				<genepattern.GPJob object at 0x112a8bc10>
# 			sraToFastq_job
# 				<genepattern.GPJob object at 0x112a8b350>
# 			sraToFastq_rvs_reads
# 				http://genepattern.broadinstitute.org/gp/jobResults/971936/SRR1039520_2.fastq.gz
# 	N080611
# 		treated
# 			fastqc_fwd_job
# 				<genepattern.GPJob object at 0x1128f6550>
# 			accession
# 				SRR1039517
# 			sraToFastq_fwd_reads
# 				http://genepattern.broadinstitute.org/gp/jobResults/971934/SRR1039517_1.fastq.gz
# 			fastqc_fwd_report
# 				http://genepattern.broadinstitute.org/gp/jobResults/974741/SRR1039517_1_fastqc/fastqc_report.html
# 			fastqc_rvs_job
# 				<genepattern.GPJob object at 0x1128f6710>
# 			sraToFastq_job
# 				<genepattern.GPJob object at 0x112a8bf90>
# 			sraToFastq_rvs_reads
# 				http://genepattern.broadinstitute.org/gp/jobResults/971934/SRR1039517_2.fastq.gz
# 		untreated
# 			fastqc_rvs_report
# 				http://genepattern.broadinstitute.org/gp/jobResults/974737/SRR1039516_2_fastqc/fastqc_report.html
# 			fastqc_fwd_job
# 				<genepattern.GPJob object at 0x112a8b490>
# 			accession
# 				SRR1039516
# 			sraToFastq_fwd_reads
# 				http://genepattern.broadinstitute.org/gp/jobResults/971933/SRR1039516_1.fastq.gz
# 			fastqc_fwd_report
# 				http://genepattern.broadinstitute.org/gp/jobResults/974736/SRR1039516_1_fastqc/fastqc_report.html
# 			fastqc_rvs_job
# 				<genepattern.GPJob object at 0x112a8b890>
# 			sraToFastq_job
# 				<genepattern.GPJob object at 0x112a8b110>
# 			sraToFastq_rvs_reads
# 				http://genepattern.broadinstitute.org/gp/jobResults/971933/SRR1039516_2.fastq.gz

# %%
donor_dict = session_state['donor_dict']
fastqc_jobs = []
for donor_id in donor_dict.keys():
    
    #untreated
    untreated_sample_data = donor_dict[donor_id]["untreated"]
    fastqc_jobs.append(untreated_sample_data['fastqc_fwd_job'])
    fastqc_jobs.append(untreated_sample_data['fastqc_rvs_job'])
    
    #treated
    treated_sample_data = donor_dict[donor_id]["treated"]
    fastqc_jobs.append(treated_sample_data['fastqc_fwd_job'])
    fastqc_jobs.append(treated_sample_data['fastqc_rvs_job'])

# Poll GenePattern until all jobs associated with above code cell are complete
gp.pollMultipleJobs(fastqc_jobs)

for donor_id in donor_dict.keys():
    
    #untreated
    untreated_sample_data = donor_dict[donor_id]["untreated"]
    job = untreated_sample_data['fastqc_fwd_job']
    untreated_sample_data['fastqc_fwd_report'] = [gpfile.uri for gpfile in job.getOutputFiles() if "fastqc_report.html" in gpfile.uri][0]
    job = untreated_sample_data['fastqc_rvs_job']    
    untreated_sample_data['fastqc_rvs_report'] = [gpfile.uri for gpfile in job.getOutputFiles() if "fastqc_report.html" in gpfile.uri][0]
    
    #treated
    treated_sample_data = donor_dict[donor_id]["treated"]
    job = treated_sample_data['fastqc_fwd_job']
    treated_sample_data['fastqc_fwd_report'] = [gpfile.uri for gpfile in job.getOutputFiles() if "fastqc_report.html" in gpfile.uri][0]
    job = untreated_sample_data['fastqc_rvs_job']
    treated_sample_data['fastqc_rvs_report'] = [gpfile.uri for gpfile in job.getOutputFiles() if "fastqc_report.html" in gpfile.uri][0]    
    
#save session state
bp.save_session_state(session_state, session_file)

# %%
bp.print_dict(session_state)
# Out:
# donor_dict
# 	N052611
# 		treated
# 			fastqc_rvs_report
# 				http://genepattern.broadinstitute.org/gp/jobResults/974731/SRR1039512_2_fastqc/fastqc_report.html
# 			fastqc_fwd_job
# 				<genepattern.GPJob object at 0x1128f64d0>
# 			accession
# 				SRR1039513
# 			sraToFastq_fwd_reads
# 				http://genepattern.broadinstitute.org/gp/jobResults/971932/SRR1039513_1.fastq.gz
# 			fastqc_fwd_report
# 				http://genepattern.broadinstitute.org/gp/jobResults/974734/SRR1039513_1_fastqc/fastqc_report.html
# 			fastqc_rvs_job
# 				<genepattern.GPJob object at 0x1128f6610>
# 			sraToFastq_job
# 				<genepattern.GPJob object at 0x1128f63d0>
# 			sraToFastq_rvs_reads
# 				http://genepattern.broadinstitute.org/gp/jobResults/971932/SRR1039513_2.fastq.gz
# 		untreated
# 			fastqc_rvs_report
# 				http://genepattern.broadinstitute.org/gp/jobResults/974731/SRR1039512_2_fastqc/fastqc_report.html
# 			fastqc_fwd_job
# 				<genepattern.GPJob object at 0x1128f6590>
# 			accession
# 				SRR1039512
# 			sraToFastq_fwd_reads
# 				http://genepattern.broadinstitute.org/gp/jobResults/971931/SRR1039512_1.fastq.gz
# 			fastqc_fwd_report
# 				http://genepattern.broadinstitute.org/gp/jobResults/974730/SRR1039512_1_fastqc/fastqc_report.html
# 			fastqc_rvs_job
# 				<genepattern.GPJob object at 0x1128f6410>
# 			sraToFastq_job
# 				<genepattern.GPJob object at 0x1128f6190>
# 			sraToFastq_rvs_reads
# 				http://genepattern.broadinstitute.org/gp/jobResults/971931/SRR1039512_2.fastq.gz
# 	N061311
# 		treated
# 			fastqc_rvs_report
# 				http://genepattern.broadinstitute.org/gp/jobResults/974694/SRR1039508_2_fastqc/fastqc_report.html
# 			fastqc_fwd_job
# 				<genepattern.GPJob object at 0x112a8b250>
# 			accession
# 				SRR1039509
# 			sraToFastq_fwd_reads
# 				http://genepattern.broadinstitute.org/gp/jobResults/971929/SRR1039508_1.fastq.gz
# 			fastqc_fwd_report
# 				http://genepattern.broadinstitute.org/gp/jobResults/974697/SRR1039509_1_fastqc/fastqc_report.html
# 			fastqc_rvs_job
# 				<genepattern.GPJob object at 0x112a8bed0>
# 			sraToFastq_job
# 				<genepattern.GPJob object at 0x112a8b410>
# 			sraToFastq_rvs_reads
# 				http://genepattern.broadinstitute.org/gp/jobResults/971929/SRR1039508_2.fastq.gz
# 		untreated
# 			fastqc_rvs_report
# 				http://genepattern.broadinstitute.org/gp/jobResults/974694/SRR1039508_2_fastqc/fastqc_report.html
# 			fastqc_fwd_job
# 				<genepattern.GPJob object at 0x112a8b590>
# 			accession
# 				SRR1039508
# 			sraToFastq_fwd_reads
# 				http://genepattern.broadinstitute.org/gp/jobResults/971929/SRR1039508_1.fastq.gz
# 			fastqc_fwd_report
# 				http://genepattern.broadinstitute.org/gp/jobResults/974693/SRR1039508_1_fastqc/fastqc_report.html
# 			fastqc_rvs_job
# 				<genepattern.GPJob object at 0x112a8bd10>
# 			sraToFastq_job
# 				<genepattern.GPJob object at 0x112a8b090>
# 			sraToFastq_rvs_reads
# 				http://genepattern.broadinstitute.org/gp/jobResults/971929/SRR1039508_2.fastq.gz
# 	N061011
# 		treated
# 			fastqc_rvs_report
# 				http://genepattern.broadinstitute.org/gp/jobResults/974747/SRR1039520_2_fastqc/fastqc_report.html
# 			fastqc_fwd_job
# 				<genepattern.GPJob object at 0x1128f6110>
# 			accession
# 				SRR1039521
# 			sraToFastq_fwd_reads
# 				http://genepattern.broadinstitute.org/gp/jobResults/971937/SRR1039521_1.fastq.gz
# 			fastqc_fwd_report
# 				http://genepattern.broadinstitute.org/gp/jobResults/974751/SRR1039521_1_fastqc/fastqc_report.html
# 			fastqc_rvs_job
# 				<genepattern.GPJob object at 0x1128f62d0>
# 			sraToFastq_job
# 				<genepattern.GPJob object at 0x1128f6390>
# 			sraToFastq_rvs_reads
# 				http://genepattern.broadinstitute.org/gp/jobResults/971937/SRR1039521_2.fastq.gz
# 		untreated
# 			fastqc_rvs_report
# 				http://genepattern.broadinstitute.org/gp/jobResults/974747/SRR1039520_2_fastqc/fastqc_report.html
# 			fastqc_fwd_job
# 				<genepattern.GPJob object at 0x112a8bf10>
# 			accession
# 				SRR1039520
# 			sraToFastq_fwd_reads
# 				http://genepattern.broadinstitute.org/gp/jobResults/971936/SRR1039520_1.fastq.gz
# 			fastqc_fwd_report
# 				http://genepattern.broadinstitute.org/gp/jobResults/974746/SRR1039520_1_fastqc/fastqc_report.html
# 			fastqc_rvs_job
# 				<genepattern.GPJob object at 0x112a8bc10>
# 			sraToFastq_job
# 				<genepattern.GPJob object at 0x112a8b350>
# 			sraToFastq_rvs_reads
# 				http://genepattern.broadinstitute.org/gp/jobResults/971936/SRR1039520_2.fastq.gz
# 	N080611
# 		treated
# 			fastqc_rvs_report
# 				http://genepattern.broadinstitute.org/gp/jobResults/974737/SRR1039516_2_fastqc/fastqc_report.html
# 			fastqc_fwd_job
# 				<genepattern.GPJob object at 0x1128f6550>
# 			accession
# 				SRR1039517
# 			sraToFastq_fwd_reads
# 				http://genepattern.broadinstitute.org/gp/jobResults/971934/SRR1039517_1.fastq.gz
# 			fastqc_fwd_report
# 				http://genepattern.broadinstitute.org/gp/jobResults/974741/SRR1039517_1_fastqc/fastqc_report.html
# 			fastqc_rvs_job
# 				<genepattern.GPJob object at 0x1128f6710>
# 			sraToFastq_job
# 				<genepattern.GPJob object at 0x112a8bf90>
# 			sraToFastq_rvs_reads
# 				http://genepattern.broadinstitute.org/gp/jobResults/971934/SRR1039517_2.fastq.gz
# 		untreated
# 			fastqc_rvs_report
# 				http://genepattern.broadinstitute.org/gp/jobResults/974737/SRR1039516_2_fastqc/fastqc_report.html
# 			fastqc_fwd_job
# 				<genepattern.GPJob object at 0x112a8b490>
# 			accession
# 				SRR1039516
# 			sraToFastq_fwd_reads
# 				http://genepattern.broadinstitute.org/gp/jobResults/971933/SRR1039516_1.fastq.gz
# 			fastqc_fwd_report
# 				http://genepattern.broadinstitute.org/gp/jobResults/974736/SRR1039516_1_fastqc/fastqc_report.html
# 			fastqc_rvs_job
# 				<genepattern.GPJob object at 0x112a8b890>
# 			sraToFastq_job
# 				<genepattern.GPJob object at 0x112a8b110>
# 			sraToFastq_rvs_reads
# 				http://genepattern.broadinstitute.org/gp/jobResults/971933/SRR1039516_2.fastq.gz

# %%
from IPython.html import widgets
from IPython.display import display
from IPython.display import clear_output
from IPython.display import HTML

donor_dict = session_state["donor_dict"]

donor_id_list = [None]
donor_id_list.extend(session_state["donor_dict"].keys())

box = widgets.ContainerWidget()
step1 = widgets.DropdownWidget(values= donor_id_list)
step2 = widgets.DropdownWidget(values=[None,"untreated", "treated"], visible=False)
step3 = widgets.DropdownWidget(values=[None,"fastqc_fwd_report", "fastqc_rvs_report"], visible=False)
box.children = [step1, step2, step3]
display(box)
box.remove_class('vbox')
box.add_class('hbox')

def step1_change(name, old, new):
    step2.visible = True
step1.on_trait_change(step1_change, 'value')

def step2_change(name, old, new):
    step3.visible = True
step2.on_trait_change(step2_change, 'value')

def step3_change(name, old, new):
    clear_output()
    if step1.value is not None and step2.value is not None and new is not None:
        report_url = donor_dict[step1.value][step2.value][new]
        print(report_url)
        display(HTML('<iframe src=%s width=1000 height=600</iframe>)' % report_url))

step3.on_trait_change(step3_change, 'value')
# Out:
# http://genepattern.broadinstitute.org/gp/jobResults/974747/SRR1039520_2_fastqc/fastqc_report.html
# <iframe src=http://genepattern.broadinstitute.org/gp/jobResults/974747/SRR1039520_2_fastqc/fastqc_report.html width=1000 height=600</iframe>)

# %% [markdown]
# #STEP 3: Run Trimmomatic on all paired fastq files

# %% [markdown]
# ## Widget-based job launch for single sample

# %% [markdown]
# ## Widget-based retrieval of job status

# %% [markdown]
# ## Programmatic launching of jobs for multiple samples

# %%
session_state = bp.load_session_state(session_file)

# %%
import copy

donor_dict = session_state["donor_dict"]

LSID = "urn:lsid:broad.mit.edu:cancer.software.genepattern.module.analysis:00341:1"

output_filename_base = "<input_file.1_basename>"
phred_encoding = "phred33"
create_trimlog = "no"

adapter_clip_sequence_file = "TruSeq2-PE.fa"
adapter_clip_seed_mismatches = "2"
adapter_clip_palindrome_clip_threshold = "15"
adapter_clip_keep_both_reads = "true"
min_read_length = "50"
output_filename_base = "<input_file.1_basename>"
phred_encoding = "phred33"
create_trimlog = "no"

job_spec_template = gp.JobSpec()
job_spec_template.setLSID(LSID)
job_spec_template.setParameter("output.filename.base", output_filename_base)
job_spec_template.setParameter("phred.encoding", phred_encoding)
job_spec_template.setParameter("create.trimlog", create_trimlog)
job_spec_template.setParameter("adapter.clip.sequence.file", adapter_clip_sequence_file)
job_spec_template.setParameter("adapter.clip.seed.mismatches", adapter_clip_seed_mismatches)
job_spec_template.setParameter("adpater.clip.palindrome.clip.threshold", adapter_clip_palindrome_clip_threshold)
job_spec_template.setParameter("adapter.clip.keep.both.reads", adapter_clip_keep_both_reads)
job_spec_template.setParameter("min.read.length", min_read_length)

#for donor_id in donor_dict.keys():
for donor_id in ["N061311"]:
    
    #untreated
    
    job_spec = copy.deepcopy(job_spec_template)
    job_spec.setParameter("input.file.1", untreated_sample_data['sraToFastq_fwd_reads'])
    job_spec.setParameter("input.file.2", untreated_sample_data['sraToFastq_rvs_reads'])
    job = gp.runJob(job_spec, waitUntilDone = False)
    untreated_sample_data['trimmomatic_job'] = job
    
    #treated
    
    treated_sample_data = donor_dict[donor_id]["treated"]

    job_spec = copy.deepcopy(job_spec_template)
    job_spec.setParameter("input.file.1", treated_sample_data['sraToFastq_fwd_reads'])
    job_spec.setParameter("input.file.2", treated_sample_data['sraToFastq_rvs_reads'])
    job = gp.runJob(job_spec, waitUntilDone = False)
    treated_sample_data['trimmomatic_job'] = job                  

bp.save_session_state(session_state, session_file)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-85-2bdae3275292> in <module>()
#      37     job_spec.setParameter("input.file.1", untreated_sample_data['sraToFastq_fwd_reads'])
#      38     job_spec.setParameter("input.file.2", untreated_sample_data['sraToFastq_rvs_reads'])
# ---> 39     job = gp.runJob(job_spec, waitUntilDone = False)
#      40     untreated_sample_data['trimmomatic_job'] = job
#      41
#
# /Users/birger/Desktop/GenePatternNotebook/Client/genepattern.pyc in runJob(jobspec, serverData, waitUntilDone)
#     509     request.add_header('Content-Type', 'application/json')
#     510     request.add_header('User-Agent', 'GenePatternRest')
# --> 511     response = urllib2.urlopen(request, jsonString)
#     512     if response.getcode() != 201:
#     513         print " job POST failed, status code = %i" % response.getcode()
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/urllib2.pyc in urlopen(url, data, timeout)
#     125     if _opener is None:
#     126         _opener = build_opener()
# --> 127     return _opener.open(url, data, timeout)
#     128
#     129 def install_opener(opener):
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/urllib2.pyc in open(self, fullurl, data, timeout)
#     408         for processor in self.process_response.get(protocol, []):
#     409             meth = getattr(processor, meth_name)
# --> 410             response = meth(req, response)
#     411
#     412         return response
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/urllib2.pyc in http_response(self, request, response)
#     521         if not (200 <= code < 300):
#     522             response = self.parent.error(
# --> 523                 'http', request, response, code, msg, hdrs)
#     524
#     525         return response
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/urllib2.pyc in error(self, proto, *args)
#     446         if http_err:
#     447             args = (dict, 'default', 'http_error_default') + orig_args
# --> 448             return self._call_chain(*args)
#     449
#     450 # XXX probably also want an abstract factory that knows when it makes
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/urllib2.pyc in _call_chain(self, chain, kind, meth_name, *args)
#     380             func = getattr(handler, meth_name)
#     381
# --> 382             result = func(*args)
#     383             if result is not None:
#     384                 return result
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/urllib2.pyc in http_error_default(self, req, fp, code, msg, hdrs)
#     529 class HTTPDefaultErrorHandler(BaseHandler):
#     530     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 531         raise HTTPError(req.get_full_url(), code, msg, hdrs, fp)
#     532
#     533 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 500: Internal Server Error
